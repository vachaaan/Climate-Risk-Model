# %%
#==========================================
# Title:  Climate Credit Risk Model
# Author: Vachan
# Email : vachan@iitb.ac.in
#==========================================

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import json

# %%
def calculate_pd(log_odds):
    """Converts log-odds to a probability."""
    return 1 / (1 + np.exp(-log_odds))

# %%
def load_pd_model(file_path):
    """Loads the pre-trained PD model details from a JSON file."""
    print(f"--- Loading PD Model details from {file_path} ---")
    try:
        with open(file_path, 'r') as f:
            pd_model_details = json.load(f)
        return pd_model_details
    except FileNotFoundError:
        print(f"Error: The model details file was not found at {file_path}")
        print("Please ensure you have run the first script to generate this file.")
        return None
    except json.JSONDecodeError:
        print(f"Error: The file at {file_path} is not a valid JSON file.")
        return None

# %%
def predict_future_pd(customer_data, predicted_risk_drivers, pd_model_details):
    """
    Calculates the Probability of Default (PD) for each customer for 2026
    under various NGFS scenarios.

    Args:
        customer_data (pd.DataFrame): The original dataframe with customer-level data.
        predicted_risk_drivers (pd.DataFrame): A dataframe with the predicted 2026 values
                                               for each risk driver under each scenario.
        pd_model_details (dict): A dictionary containing the variables and coefficients
                                 of the pre-trained logistic regression model.
    """
    print("--- Starting PD Calculation for 2026 ---")

    # Get the list of variables from the PD model
    model_vars = pd_model_details['variables']
    model_coeffs = pd_model_details['coefficients']

    # We need a base set of features for each customer that are not predicted
    # Let's take the most recent known data (2021) as the base
    base_customer_df = customer_data.copy()

    # Create a list to store results
    all_scenario_pds = []

    # Iterate over each scenario from the prediction results
    for scenario in predicted_risk_drivers['Scenario'].unique():
        print(f"\n--- Calculating PD for Scenario: {scenario} ---")
        
        scenario_predictions = predicted_risk_drivers[predicted_risk_drivers['Scenario'] == scenario]
        
        # Start with the base customer data for this scenario
        scenario_customer_df = base_customer_df.copy()
        
        # Update the customer data with the predicted 2026 risk driver values for this scenario
        for _, row in scenario_predictions.iterrows():
            driver = row['risk_driver']
            predicted_value = row['predicted_value_2026']
            if driver in scenario_customer_df.columns:
                print(f"  Updating '{driver}' with predicted value: {predicted_value:.4f}")
                scenario_customer_df[driver] = predicted_value

        # --- Calculate Log-Odds ---
        # Start with the intercept (const)
        log_odds = model_coeffs.get('const', 0)
        
        print("  Calculating log-odds using formula: const + (coeff1 * var1) + ...")
        # Add the weighted value of each variable
        for var in model_vars:
            if var in model_coeffs and var in scenario_customer_df.columns:
                log_odds += model_coeffs[var] * scenario_customer_df[var]
        
        # --- Calculate PD ---
        scenario_customer_df['predicted_pd_2026'] = calculate_pd(log_odds)
        scenario_customer_df['Scenario'] = scenario
        
        all_scenario_pds.append(scenario_customer_df[['customer_id', 'Scenario', 'predicted_pd_2026']])

    # --- Combine and Summarize Results ---
    if all_scenario_pds:
        final_pd_df = pd.concat(all_scenario_pds, ignore_index=True)
        df1=final_pd_df
        df1.to_csv('Final PD.csv')
        
        print("\n\n==================== FINAL 2026 PD PREDICTIONS ====================")
        print("\n--- Sample PDs for individual customers ---")
        print(final_pd_df.sample(10))

        print("\n--- Average Predicted PD per Scenario ---")
        pd_summary = final_pd_df.groupby('Scenario')['predicted_pd_2026'].mean().reset_index()
        pd_summary.rename(columns={'predicted_pd_2026': 'average_pd_2026'}, inplace=True)
        print(pd_summary)
    else:
        print("\nCould not generate PD predictions.")

# %%
# --- Main Execution ---
if __name__ == '__main__':
    try:
        # --- 1. Define File Paths ---
        pd_model_file = "C:/Users/vacha/OneDrive - Indian Institute of Technology Bombay/Climate Finance/pd_model_details.json"
        customer_data_file = "C:/Users/vacha/OneDrive - Indian Institute of Technology Bombay/Climate Finance/Retail Portfoilio Research/Auto Risk Kaggle/data.csv"
        predicted_drivers_file = "C:/Users/vacha/predicted_risk_drivers_2026.csv" # This file is created by the previous script.

        # --- 2. Load All Required Data ---
        pd_model = load_pd_model(pd_model_file)
        if pd_model is None:
            # Stop execution if model can't be loaded
            exit()

        customer_df = pd.read_csv(customer_data_file)
        
        # Load the results from the previous script.
        try:
            predicted_drivers_df = pd.read_csv(predicted_drivers_file)
            print(f"--- Successfully loaded predicted risk drivers from '{predicted_drivers_file}' ---")
        except FileNotFoundError:
            print(f"CRITICAL ERROR: The file '{predicted_drivers_file}' was not found.")
            print("Please run the previous script (future_data_simulation_model.py) to generate it.")
            exit() # Stop execution if the predictions file is missing.

        print("-" * 55)

        # --- 3. Calculate and Display Future PD ---
        predict_future_pd(
            customer_data=customer_df,
            predicted_risk_drivers=predicted_drivers_df,
            pd_model_details=pd_model
        )

    except FileNotFoundError as e:
        print(f"\nError: A required file was not found. Details: {e}")
    except Exception as e:
        print(f"An error occurred: {e}")
# Out:
# --- Loading PD Model details from C:/Users/vacha/OneDrive - Indian Institute of Technology Bombay/Climate Finance/pd_model_details.json ---
# --- Successfully loaded predicted risk drivers from 'C:/Users/vacha/predicted_risk_drivers_2026.csv' ---
# -------------------------------------------------------
# --- Starting PD Calculation for 2026 ---
#
# --- Calculating PD for Scenario: Baseline ---
#   Updating 'ltv' with predicted value: 63.9864
#   Updating 'average_age' with predicted value: 13.0878
#   Updating 'credit_score' with predicted value: 306.3839
#   Updating 'last_six_month_defaulted_no' with predicted value: 0.0154
#   Updating 'credit_history' with predicted value: 18.2206
#   Calculating log-odds using formula: const + (coeff1 * var1) + ...
#
# --- Calculating PD for Scenario: DAPS_AFR_R ---
#   Updating 'ltv' with predicted value: 66.5777
#   Updating 'average_age' with predicted value: 12.0912
#   Updating 'credit_score' with predicted value: 306.3407
#   Updating 'last_six_month_defaulted_no' with predicted value: 0.0148
#   Updating 'credit_history' with predicted value: 17.2240
#   Calculating log-odds using formula: const + (coeff1 * var1) + ...
#
# --- Calculating PD for Scenario: DAPS_AFR_R_run1 ---
#   Updating 'ltv' with predicted value: 66.1698
#   Updating 'average_age' with predicted value: 12.2360
#   Updating 'credit_score' with predicted value: 305.9587
#   Updating 'last_six_month_defaulted_no' with predicted value: 0.0145
#   Updating 'credit_history' with predicted value: 17.3688
#   Calculating log-odds using formula: const + (coeff1 * var1) + ...
#
# --- Calculating PD for Scenario: DAPS_ASIA ---
#   Updating 'ltv' with predicted value: 10.4274
#   Updating 'average_age' with predicted value: 32.9975
#   Updating 'credit_score' with predicted value: 303.7827
#   Updating 'last_six_month_defaulted_no' with predicted value: 0.0122
#   Updating 'credit_history' with predicted value: 38.1302
#   Calculating log-odds using formula: const + (coeff1 * var1) + ...
#
# --- Calculating PD for Scenario: DAPS_ASIA_run1 ---
#   Updating 'ltv' with predicted value: 47.4859
#   Updating 'average_age' with predicted value: 19.1284
#   Updating 'credit_score' with predicted value: 304.4509
#   Updating 'last_six_month_defaulted_no' with predicted value: 0.0088
#   Updating 'credit_history' with predicted value: 24.2612
#   Calculating log-odds using formula: const + (coeff1 * var1) + ...
#
# --- Calculating PD for Scenario: DAPS_EUR ---
#   Updating 'ltv' with predicted value: 65.0886
#   Updating 'average_age' with predicted value: 12.6732
#   Updating 'credit_score' with predicted value: 306.4889
#   Updating 'last_six_month_defaulted_no' with predicted value: 0.0155
#   Updating 'credit_history' with predicted value: 17.8060
#   Calculating log-odds using formula: const + (coeff1 * var1) + ...
#
# --- Calculating PD for Scenario: DAPS_EUR_run1 ---
#   Updating 'ltv' with predicted value: 64.5242
#   Updating 'average_age' with predicted value: 12.8877
#   Updating 'credit_score' with predicted value: 306.1840
#   Updating 'last_six_month_defaulted_no' with predicted value: 0.0153
#   Updating 'credit_history' with predicted value: 18.0205
#   Calculating log-odds using formula: const + (coeff1 * var1) + ...
#
# --- Calculating PD for Scenario: DAPS_NAM ---
#   Updating 'ltv' with predicted value: 65.6255
#   Updating 'average_age' with predicted value: 12.4672
#   Updating 'credit_score' with predicted value: 306.7903
#   Updating 'last_six_month_defaulted_no' with predicted value: 0.0149
#   Updating 'credit_history' with predicted value: 17.6000
#   Calculating log-odds using formula: const + (coeff1 * var1) + ...
#
# --- Calculating PD for Scenario: DAPS_NAM_run1 ---
#   Updating 'ltv' with predicted value: 64.3059
#   Updating 'average_age' with predicted value: 12.9634
#   Updating 'credit_score' with predicted value: 306.2327
#   Updating 'last_six_month_defaulted_no' with predicted value: 0.0152
#   Updating 'credit_history' with predicted value: 18.0962
#   Calculating log-odds using formula: const + (coeff1 * var1) + ...
#
# --- Calculating PD for Scenario: DAPS_OCE ---
#   Updating 'ltv' with predicted value: 64.4903
#   Updating 'average_age' with predicted value: 12.8959
#   Updating 'credit_score' with predicted value: 306.3942
#   Updating 'last_six_month_defaulted_no' with predicted value: 0.0154
#   Updating 'credit_history' with predicted value: 18.0287
#   Calculating log-odds using formula: const + (coeff1 * var1) + ...
#
# --- Calculating PD for Scenario: DAPS_OCE_run1 ---
#   Updating 'ltv' with predicted value: 64.3974
#   Updating 'average_age' with predicted value: 12.9310
#   Updating 'credit_score' with predicted value: 306.3576
#   Updating 'last_six_month_defaulted_no' with predicted value: 0.0153
#   Updating 'credit_history' with predicted value: 18.0637
#   Calculating log-odds using formula: const + (coeff1 * var1) + ...
#
# --- Calculating PD for Scenario: DAPS_SAM ---
#   Updating 'ltv' with predicted value: 64.2804
#   Updating 'average_age' with predicted value: 12.9752
#   Updating 'credit_score' with predicted value: 306.3133
#   Updating 'last_six_month_defaulted_no' with predicted value: 0.0153
#   Updating 'credit_history' with predicted value: 18.1080
#   Calculating log-odds using formula: const + (coeff1 * var1) + ...
#
# --- Calculating PD for Scenario: DAPS_SAM_run1 ---
#   Updating 'ltv' with predicted value: 64.2723
#   Updating 'average_age' with predicted value: 12.9784
#   Updating 'credit_score' with predicted value: 306.3048
#   Updating 'last_six_month_defaulted_no' with predicted value: 0.0153
#   Updating 'credit_history' with predicted value: 18.1111
#   Calculating log-odds using formula: const + (coeff1 * var1) + ...
#
# --- Calculating PD for Scenario: DIRE ---
#   Updating 'ltv' with predicted value: 35.5427
#   Updating 'average_age' with predicted value: 23.6946
#   Updating 'credit_score' with predicted value: 305.1367
#   Updating 'last_six_month_defaulted_no' with predicted value: -0.0086
#   Updating 'credit_history' with predicted value: 28.8273
#   Calculating log-odds using formula: const + (coeff1 * var1) + ...
#
# --- Calculating PD for Scenario: DIRE_run1 ---
#   Updating 'ltv' with predicted value: 63.1820
#   Updating 'average_age' with predicted value: 13.3594
#   Updating 'credit_score' with predicted value: 305.8879
#   Updating 'last_six_month_defaulted_no' with predicted value: -0.0111
#   Updating 'credit_history' with predicted value: 18.4922
#   Calculating log-odds using formula: const + (coeff1 * var1) + ...
#
# --- Calculating PD for Scenario: HWTP ---
#   Updating 'ltv' with predicted value: 44.1765
#   Updating 'average_age' with predicted value: 20.2878
#   Updating 'credit_score' with predicted value: 305.3832
#   Updating 'last_six_month_defaulted_no' with predicted value: -1.8246
#   Updating 'credit_history' with predicted value: 25.4205
#   Calculating log-odds using formula: const + (coeff1 * var1) + ...
#
# --- Calculating PD for Scenario: HWTP_run1 ---
#   Updating 'ltv' with predicted value: 49.0029
#   Updating 'average_age' with predicted value: 18.4788
#   Updating 'credit_score' with predicted value: 305.3478
#   Updating 'last_six_month_defaulted_no' with predicted value: -1.8123
#   Updating 'credit_history' with predicted value: 23.6115
#   Calculating log-odds using formula: const + (coeff1 * var1) + ...
#
# --- Calculating PD for Scenario: SWUC ---
#   Updating 'ltv' with predicted value: 63.9864
#   Updating 'average_age' with predicted value: 13.0878
#   Updating 'credit_score' with predicted value: 306.3839
#   Updating 'last_six_month_defaulted_no' with predicted value: 0.0154
#   Updating 'credit_history' with predicted value: 18.2206
#   Calculating log-odds using formula: const + (coeff1 * var1) + ...
#
# --- Calculating PD for Scenario: SWUC_run1 ---
#   Updating 'ltv' with predicted value: 63.9864
#   Updating 'average_age' with predicted value: 13.0878
#   Updating 'credit_score' with predicted value: 306.3839
#   Updating 'last_six_month_defaulted_no' with predicted value: 0.0154
#   Updating 'credit_history' with predicted value: 18.2206
#   Calculating log-odds using formula: const + (coeff1 * var1) + ...
#
#
# ==================== FINAL 2026 PD PREDICTIONS ====================
#
# --- Sample PDs for individual customers ---
#          customer_id       Scenario  predicted_pd_2026
# 3731384      5184766      SWUC_run1           0.134742
# 2549091      4989763  DAPS_SAM_run1           0.135563
# 1563231      4529445       DAPS_NAM           0.139453
# 1831070      5784448       DAPS_OCE           0.136187
# 1089820      6130239       DAPS_EUR           0.137920
# 3701633      4252069      SWUC_run1           0.134742
# 2916376      4979148      DIRE_run1           0.131666
# 1162453      4418569       DAPS_EUR           0.137920
# 1091231      4670179       DAPS_EUR           0.137920
# 2496751      4569014  DAPS_SAM_run1           0.135563
#
# --- Average Predicted PD per Scenario ---
#            Scenario  average_pd_2026
# 0          Baseline         0.134742
# 1        DAPS_AFR_R         0.142304
# 2   DAPS_AFR_R_run1         0.141099
# 3         DAPS_ASIA         0.040245
# 4    DAPS_ASIA_run1         0.094078
# 5          DAPS_EUR         0.137920
# 6     DAPS_EUR_run1         0.136293
# 7          DAPS_NAM         0.139453
# 8     DAPS_NAM_run1         0.135661
# 9          DAPS_OCE         0.136187
# 10    DAPS_OCE_run1         0.135921
# 11         DAPS_SAM         0.135586
# 12    DAPS_SAM_run1         0.135563
# 13             DIRE         0.071586
# 14        DIRE_run1         0.131666
# 15             HWTP         0.054983
# 16        HWTP_run1         0.061656
# 17             SWUC         0.134742
# 18        SWUC_run1         0.134742
