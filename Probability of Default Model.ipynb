# %%
#==========================================
# Title:  Climate Credit Risk Model
# Author: Vachan
# Email : vachan@iitb.ac.in
#==========================================

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from itertools import combinations
import seaborn as sns
import matplotlib.pyplot as plt
import json

# %%
def find_best_logit_model(data, target_col, risk_drivers):
    """
    Iterates through all combinations of risk drivers to find the best logistic
    regression model based on BIC, trained on the entire dataset. Also checks
    for multicollinearity using VIF.

    Args:
        data (pd.DataFrame): The input dataframe.
        target_col (str): The name of the dependent variable (target).
        risk_drivers (list): A list of column names for the independent
                               variables (risk drivers).

    Returns:
        tuple: A tuple containing the best model object, the best
               combination of features, and the best BIC score.
    """
    best_model_result = None
    best_combination = None
    lowest_bic = float('inf')
    results = []

    print("--- Starting Model Search ---")

    # --- 1. Correlation Analysis ---
    print("\n--- Correlation Matrix of Risk Drivers ---")
    correlation_matrix = data[risk_drivers].corr()
    print(correlation_matrix)
    plt.figure(figsize=(12, 10))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
    plt.title('Correlation Matrix of Risk Drivers')
    plt.show()
    print("-" * 40)

    # --- 2. Multicollinearity Check using VIF ---
    print("\n--- Variance Inflation Factor (VIF) Check ---")
    X_for_vif = sm.add_constant(data[risk_drivers].astype(float))
    vif_data = pd.DataFrame()
    vif_data["feature"] = X_for_vif.columns
    vif_data["VIF"] = [variance_inflation_factor(X_for_vif.values, i)
                       for i in range(X_for_vif.shape[1])]
    print(vif_data[vif_data["feature"] != "const"])
    print("(Note: A VIF > 5 or 10 suggests potential multicollinearity)")
    print("-" * 55)

    # --- 3. Iterate through all combinations of risk drivers ---
    for i in range(1, len(risk_drivers) + 1):
        for combo in combinations(risk_drivers, i):
            combo_list = list(combo)
            print(f"\nTesting combination: {combo_list}")

            X = data[combo_list]
            y = data[target_col]
            X = sm.add_constant(X)

            try:
                logit_model = sm.Logit(y, X)
                result = logit_model.fit(disp=0)
                bic_score = result.bic

                # Store results for review
                results.append({
                    'Combination': combo_list,
                    'AIC': result.aic,
                    'BIC': bic_score,
                    'Pseudo_R_squared': result.prsquared
                })

                # Identify the Best Model (lower BIC is better)
                if bic_score < lowest_bic:
                    lowest_bic = bic_score
                    best_model_result = result
                    best_combination = combo_list

            except Exception as e:
                print(f"Could not fit model for combination {combo_list}. Error: {e}")

    print("\n--- Model Search Complete ---")
    results_df = pd.DataFrame(results).sort_values(by='BIC', ascending=True).reset_index(drop=True)
    print("\n--- All Model Combination Results (sorted by BIC) ---")
    print(results_df)
    print("-" * 65)

    return best_model_result, best_combination, lowest_bic

# %%
# --- Main Execution ---
if __name__ == '__main__':
    try:
        # Load the dataset
        df = pd.read_csv("C:/Users/vacha/OneDrive - Indian Institute of Technology Bombay/Climate Finance/Retail Portfoilio Research/Auto Risk Kaggle/data.csv")

        # Define Risk Drivers and Target
        risk_driver_vector = [
            'ltv', 'disburse_to_sactioned_ratio', 'average_age', 
            'credit_score', 'last_six_month_defaulted_no', 
            'credit_history', 'main_account_tenure'
        ]
        target_variable = 'loan_default'

        all_cols = risk_driver_vector + [target_variable]
        if not all(col in df.columns for col in all_cols):
            raise ValueError("One or more specified columns are not in the DataFrame.")

        df.dropna(subset=all_cols, inplace=True)
        df[target_variable] = df[target_variable].astype(int)

        # Find the best model
        best_model, combination, bic = find_best_logit_model(df, target_variable, risk_driver_vector)

        # Check if a model was successfully found before proceeding
        if best_model:
            # Print the final results
            print("\n\n--- Best Model Found ---")
            print(f"The best combination of risk drivers (based on lowest BIC) is: {combination}")
            print(f"Best Model's BIC Score: {bic:.4f}")
            print("\n--- Best Model Summary ---")
            print(best_model.summary())

            # --- Save the model details to JSON ---
            print("\n--- Saving Best PD Model Details ---")
            coefficients = best_model.params.to_dict()
            pd_model_to_save = {
                'variables': combination,
                'coefficients': coefficients
            }
            file_path_to_save = 'pd_model_details.json'
            with open(file_path_to_save, 'w') as f:
                json.dump(pd_model_to_save, f, indent=4)
            print(f"Successfully saved model details to: {file_path_to_save}")

        else:
            print("\n--- No suitable model was found. ---")
            
    except FileNotFoundError:
        print("Error: The data file was not found.")
    except Exception as e:
        print(f"An error occurred: {e}")
# Out:
# --- Starting Model Search ---
#
# --- Correlation Matrix of Risk Drivers ---
#                                   ltv  disburse_to_sactioned_ratio  \
# ltv                          1.000000                     0.000960
# disburse_to_sactioned_ratio  0.000960                     1.000000
# average_age                  0.026931                     0.007467
# credit_score                 0.087051                     0.001441
# last_six_month_defaulted_no  0.041653                     0.001267
# credit_history               0.053918                     0.004896
# main_account_tenure         -0.001319                     0.048154
#
#                              average_age  credit_score  \
# ltv                             0.026931      0.087051
# disburse_to_sactioned_ratio     0.007467      0.001441
# average_age                     1.000000      0.468580
# credit_score                    0.468580      1.000000
# last_six_month_defaulted_no     0.172883      0.162263
# credit_history                  0.758665      0.532563
# main_account_tenure             0.021030      0.020785
#
#                              last_six_month_defaulted_no  credit_history  \
# ltv                                             0.041653        0.053918
# disburse_to_sactioned_ratio                     0.001267        0.004896
# average_age                                     0.172883        0.758665
# credit_score                                    0.162263        0.532563
# last_six_month_defaulted_no                     1.000000        0.256419
# credit_history                                  0.256419        1.000000
# main_account_tenure                             0.008790        0.024538
#
#                              main_account_tenure
# ltv                                    -0.001319
# disburse_to_sactioned_ratio             0.048154
# average_age                             0.021030
# credit_score                            0.020785
# last_six_month_defaulted_no             0.008790
# credit_history                          0.024538
# main_account_tenure                     1.000000
# ----------------------------------------
#
# --- Variance Inflation Factor (VIF) Check ---
#                        feature       VIF
# 1                          ltv  1.009289
# 2  disburse_to_sactioned_ratio  1.002377
# 3                  average_age  2.394455
# 4                 credit_score  1.424438
# 5  last_six_month_defaulted_no  1.073725
# 6               credit_history  2.686913
# 7          main_account_tenure  1.003025
# (Note: A VIF > 5 or 10 suggests potential multicollinearity)
# -------------------------------------------------------
#
# Testing combination: ['ltv']
#
# Testing combination: ['disburse_to_sactioned_ratio']
#
# Testing combination: ['average_age']
#
# Testing combination: ['credit_score']
#
# Testing combination: ['last_six_month_defaulted_no']
#
# Testing combination: ['credit_history']
#
# Testing combination: ['main_account_tenure']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio']
#
# Testing combination: ['ltv', 'average_age']
#
# Testing combination: ['ltv', 'credit_score']
#
# Testing combination: ['ltv', 'last_six_month_defaulted_no']
#
# Testing combination: ['ltv', 'credit_history']
#
# Testing combination: ['ltv', 'main_account_tenure']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'average_age']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'credit_score']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'last_six_month_defaulted_no']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'credit_history']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'main_account_tenure']
#
# Testing combination: ['average_age', 'credit_score']
#
# Testing combination: ['average_age', 'last_six_month_defaulted_no']
#
# Testing combination: ['average_age', 'credit_history']
#
# Testing combination: ['average_age', 'main_account_tenure']
#
# Testing combination: ['credit_score', 'last_six_month_defaulted_no']
#
# Testing combination: ['credit_score', 'credit_history']
#
# Testing combination: ['credit_score', 'main_account_tenure']
#
# Testing combination: ['last_six_month_defaulted_no', 'credit_history']
#
# Testing combination: ['last_six_month_defaulted_no', 'main_account_tenure']
#
# Testing combination: ['credit_history', 'main_account_tenure']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'average_age']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'credit_score']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'last_six_month_defaulted_no']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'credit_history']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'main_account_tenure']
#
# Testing combination: ['ltv', 'average_age', 'credit_score']
#
# Testing combination: ['ltv', 'average_age', 'last_six_month_defaulted_no']
#
# Testing combination: ['ltv', 'average_age', 'credit_history']
#
# Testing combination: ['ltv', 'average_age', 'main_account_tenure']
#
# Testing combination: ['ltv', 'credit_score', 'last_six_month_defaulted_no']
#
# Testing combination: ['ltv', 'credit_score', 'credit_history']
#
# Testing combination: ['ltv', 'credit_score', 'main_account_tenure']
#
# Testing combination: ['ltv', 'last_six_month_defaulted_no', 'credit_history']
#
# Testing combination: ['ltv', 'last_six_month_defaulted_no', 'main_account_tenure']
#
# Testing combination: ['ltv', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'average_age', 'credit_score']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'average_age', 'last_six_month_defaulted_no']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'average_age', 'credit_history']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'average_age', 'main_account_tenure']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'credit_score', 'last_six_month_defaulted_no']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'credit_score', 'credit_history']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'credit_score', 'main_account_tenure']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'last_six_month_defaulted_no', 'credit_history']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'last_six_month_defaulted_no', 'main_account_tenure']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['average_age', 'credit_score', 'last_six_month_defaulted_no']
#
# Testing combination: ['average_age', 'credit_score', 'credit_history']
#
# Testing combination: ['average_age', 'credit_score', 'main_account_tenure']
#
# Testing combination: ['average_age', 'last_six_month_defaulted_no', 'credit_history']
#
# Testing combination: ['average_age', 'last_six_month_defaulted_no', 'main_account_tenure']
#
# Testing combination: ['average_age', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['credit_score', 'last_six_month_defaulted_no', 'credit_history']
#
# Testing combination: ['credit_score', 'last_six_month_defaulted_no', 'main_account_tenure']
#
# Testing combination: ['credit_score', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['last_six_month_defaulted_no', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'average_age', 'credit_score']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'average_age', 'last_six_month_defaulted_no']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'average_age', 'credit_history']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'average_age', 'main_account_tenure']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'credit_score', 'last_six_month_defaulted_no']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'credit_score', 'credit_history']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'credit_score', 'main_account_tenure']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'last_six_month_defaulted_no', 'credit_history']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'last_six_month_defaulted_no', 'main_account_tenure']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['ltv', 'average_age', 'credit_score', 'last_six_month_defaulted_no']
#
# Testing combination: ['ltv', 'average_age', 'credit_score', 'credit_history']
#
# Testing combination: ['ltv', 'average_age', 'credit_score', 'main_account_tenure']
#
# Testing combination: ['ltv', 'average_age', 'last_six_month_defaulted_no', 'credit_history']
#
# Testing combination: ['ltv', 'average_age', 'last_six_month_defaulted_no', 'main_account_tenure']
#
# Testing combination: ['ltv', 'average_age', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['ltv', 'credit_score', 'last_six_month_defaulted_no', 'credit_history']
#
# Testing combination: ['ltv', 'credit_score', 'last_six_month_defaulted_no', 'main_account_tenure']
#
# Testing combination: ['ltv', 'credit_score', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['ltv', 'last_six_month_defaulted_no', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'average_age', 'credit_score', 'last_six_month_defaulted_no']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'average_age', 'credit_score', 'credit_history']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'average_age', 'credit_score', 'main_account_tenure']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'average_age', 'last_six_month_defaulted_no', 'credit_history']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'average_age', 'last_six_month_defaulted_no', 'main_account_tenure']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'average_age', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'credit_score', 'last_six_month_defaulted_no', 'credit_history']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'credit_score', 'last_six_month_defaulted_no', 'main_account_tenure']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'credit_score', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'last_six_month_defaulted_no', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['average_age', 'credit_score', 'last_six_month_defaulted_no', 'credit_history']
#
# Testing combination: ['average_age', 'credit_score', 'last_six_month_defaulted_no', 'main_account_tenure']
#
# Testing combination: ['average_age', 'credit_score', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['average_age', 'last_six_month_defaulted_no', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['credit_score', 'last_six_month_defaulted_no', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'average_age', 'credit_score', 'last_six_month_defaulted_no']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'average_age', 'credit_score', 'credit_history']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'average_age', 'credit_score', 'main_account_tenure']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'average_age', 'last_six_month_defaulted_no', 'credit_history']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'average_age', 'last_six_month_defaulted_no', 'main_account_tenure']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'average_age', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'credit_score', 'last_six_month_defaulted_no', 'credit_history']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'credit_score', 'last_six_month_defaulted_no', 'main_account_tenure']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'credit_score', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'last_six_month_defaulted_no', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['ltv', 'average_age', 'credit_score', 'last_six_month_defaulted_no', 'credit_history']
#
# Testing combination: ['ltv', 'average_age', 'credit_score', 'last_six_month_defaulted_no', 'main_account_tenure']
#
# Testing combination: ['ltv', 'average_age', 'credit_score', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['ltv', 'average_age', 'last_six_month_defaulted_no', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['ltv', 'credit_score', 'last_six_month_defaulted_no', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'average_age', 'credit_score', 'last_six_month_defaulted_no', 'credit_history']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'average_age', 'credit_score', 'last_six_month_defaulted_no', 'main_account_tenure']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'average_age', 'credit_score', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'average_age', 'last_six_month_defaulted_no', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'credit_score', 'last_six_month_defaulted_no', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['average_age', 'credit_score', 'last_six_month_defaulted_no', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'average_age', 'credit_score', 'last_six_month_defaulted_no', 'credit_history']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'average_age', 'credit_score', 'last_six_month_defaulted_no', 'main_account_tenure']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'average_age', 'credit_score', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'average_age', 'last_six_month_defaulted_no', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'credit_score', 'last_six_month_defaulted_no', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['ltv', 'average_age', 'credit_score', 'last_six_month_defaulted_no', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['disburse_to_sactioned_ratio', 'average_age', 'credit_score', 'last_six_month_defaulted_no', 'credit_history', 'main_account_tenure']
#
# Testing combination: ['ltv', 'disburse_to_sactioned_ratio', 'average_age', 'credit_score', 'last_six_month_defaulted_no', 'credit_history', 'main_account_tenure']
#
# --- Model Search Complete ---
#
# --- All Model Combination Results (sorted by BIC) ---
#                                            Combination            AIC  \
# 0    [ltv, average_age, credit_score, last_six_mont...  183778.912407
# 1    [ltv, average_age, credit_score, last_six_mont...  183779.215683
# 2    [ltv, disburse_to_sactioned_ratio, average_age...  183779.976908
# 3    [ltv, credit_score, last_six_month_defaulted_n...  183807.754083
# 4    [ltv, disburse_to_sactioned_ratio, average_age...  183780.227708
# ..                                                 ...            ...
# 122         [disburse_to_sactioned_ratio, average_age]  186598.539801
# 123  [disburse_to_sactioned_ratio, average_age, mai...  186599.730382
# 124                      [disburse_to_sactioned_ratio]  186704.200503
# 125                              [main_account_tenure]  186704.647948
# 126  [disburse_to_sactioned_ratio, main_account_ten...  186705.697181
#
#                BIC  Pseudo_R_squared
# 0    183840.140347          0.015716
# 1    183850.648280          0.015725
# 2    183851.409504          0.015721
# 3    183858.777366          0.015551
# 4    183861.864961          0.015730
# ..             ...               ...
# 122  186629.153771          0.000582
# 123  186640.549009          0.000586
# 124  186724.609816          0.000005
# 125  186725.057261          0.000003
# 126  186736.311151          0.000008
#
# [127 rows x 4 columns]
# -----------------------------------------------------------------
#
#
# --- Best Model Found ---
# The best combination of risk drivers (based on lowest BIC) is: ['ltv', 'average_age', 'credit_score', 'last_six_month_defaulted_no', 'credit_history']
# Best Model's BIC Score: 183840.1403
#
# --- Best Model Summary ---
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           loan_default   No. Observations:               199717
# Model:                          Logit   Df Residuals:                   199711
# Method:                           MLE   Df Model:                            5
# Date:                Mon, 30 Jun 2025   Pseudo R-squ.:                 0.01572
# Time:                        16:23:02   Log-Likelihood:                -91883.
# converged:                       True   LL-Null:                       -93351.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                          -3.2502      0.044    -73.741      0.000      -3.337      -3.164
# ltv                             0.0244      0.001     42.571      0.000       0.023       0.026
# average_age                     0.0037      0.001      5.612      0.000       0.002       0.005
# credit_score                   -0.0005   2.15e-05    -23.199      0.000      -0.001      -0.000
# last_six_month_defaulted_no     0.2715      0.015     18.651      0.000       0.243       0.300
# credit_history                 -0.0039      0.000     -8.264      0.000      -0.005      -0.003
# ===============================================================================================
#
# --- Saving Best PD Model Details ---
# Successfully saved model details to: pd_model_details.json
